# %% [markdown]
# ### **Grand Canyon Sandbar Timelapse creator**
#
# A script to create timelapses from sandbar imagery (testing script)
#
# Created by Ryan E. Lima ryan.lima@nau.edu for the USGS GCMRC
#
# #### To Do List
# 1.  Turn into python Package
# 2.  improve commenting
# 3.  create in-depth readme
# 4.  add error messages
# 5.  provide sample dataset

# %%
import re
import os
import cv2
import glob
from datetime import datetime

# %%
##------------ get list of images----------------------------#
# sample image directories from sandbars for which timelapses will be made
image_dir30 ='M:/Ryan_Lima/Remote Cameras/full_res/RC0307Rf' # location on local PC or attached drive
image_dir22_web = 'M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra' # location on local PC or attached drive


def get_image_files(directory):
    """
    Get a list of image file paths from the given directory.
    Supports .jpg, .JPG, .jpeg, .JPEG file extensions.
    """
    extensions = ['jpg', 'JPG', 'jpeg', 'JPEG']
    files = []
    for ext in extensions:
        files.extend(glob.glob(os.path.join(directory, f'*.{ext}')))
    return files

image_files = get_image_files(image_dir30)
print(image_files[1])
# Out:
# M:/Ryan_Lima/Remote Cameras/full_res/RC0307Rf\RC0307Rf_20141111_1657.JPG

# %%
def parse_filename(filename):
    """
    Parse the filename to extract date and time.
    Handles filenames with optional '_web' before the extension.
    Returns a datetime object if the filename matches the pattern, otherwise None.
    """
    pattern = r'RC\d{4}[RL][a-z]?_(\d{8})_(\d{4})(_web)?.jpg'
    match = re.match(pattern, filename)
    if match:
        date_str, time_str, _ = match.groups()
        return datetime.strptime(date_str + time_str, '%Y%m%d%H%M')
    return None

def get_file_size(file_path):
    """
    Get and print the file size of the given image file.
    """
    size_bytes = os.path.getsize(file_path)
    size_kb = size_bytes / 1024
    print(f"File: {file_path}, Size: {size_kb:.2f} KB")
    return size_kb

def resize_image(image, scale_percent):
    """
    Resize the given image by the specified scale percentage.
    """
    width = int(image.shape[1] * scale_percent / 100)
    height = int(image.shape[0] * scale_percent / 100)
    dim = (width, height)
    return cv2.resize(image, dim, interpolation=cv2.INTER_AREA)
    
def filter_images(folder_path, start_time, end_time):
    """
    Filter images in the folder based on the specified time range.
    Returns a list of filenames that fall within the time range, sorted by datetime.
    """
    filtered_files = []
    for filename in os.listdir(folder_path):
        file_datetime = parse_filename(filename)
        if file_datetime and start_time <= file_datetime.time() <= end_time:
            filtered_files.append((file_datetime, os.path.join(folder_path, filename)))

    # Sort the list by datetime
    filtered_files.sort(key=lambda x: x[0])

    # Extract just the file paths
    sorted_files = [file[1] for file in filtered_files]
    print(f'The Directory {folder_path} contains {len(sorted_files)} within the specified start_time, end_time range')
    print(f'The first image is {sorted_files[0]} and the last image of the series is {sorted_files[-1]}')
    return sorted_files


def put_date_on_image(img, date_str):
    """
    Puts the date string on the bottom-left corner of the image.
    """
    font = cv2.FONT_HERSHEY_SIMPLEX
    font_scale = 2
    font_color = (255, 255, 255)  # white color
    line_type = 3

    cv2.putText(img, date_str, 
                (10, img.shape[0] - 10),  # position at bottom left
                font, 
                font_scale, 
                font_color, 
                line_type)

# def create_timelapse(site_name, image_files, out_dir = os.getcwd() frame_rate=30):
#     """
#     Create a timelapse video from the given image files.
#     Includes the site name and creation date in the video filename.
#     """
#     print(f'creating timelapse beginning with {image_files[0]} and ending with {image_files[-1]}') 
#     # Get the current date for the filename
#     current_date = datetime.now().strftime('%Y%m%d')
#     output_file = f'{out_dir + os.sep}{site_name}_timelapse_{current_date}.avi'  # Changed to .avi
#     output_file = os.path.join(os.getcwd(), output_file)  # Ensuring path compatibility

#     # Read the first image to determine the video resolution
#     frame = cv2.imread(image_files[0])
#     height, width, layers = frame.shape
#     size = (width, height)

#     # Create VideoWriter object with XVID codec
#     out = cv2.VideoWriter(output_file, cv2.VideoWriter_fourcc(*'XVID'), frame_rate, size)
#     n_images = 1
#     nn = len(image_files)
#     for filename in image_files:
#         print(f'processing image {filename} - {n_images} out of {nn}') 
#         img = cv2.imread(filename)
#         date_time = parse_filename(os.path.basename(filename))
#         date_str = date_time.strftime('%Y-%m-%d %H:%M')
#         put_date_on_image(img, date_str)
#         out.write(img)
#         n_images = n_images+1

#     out.release()
#     return output_file

def create_timelapse(site_name, image_files,out_dir = os.getcwd(),frame_rate=7, resize_percent=100):
    """
    Create a timelapse video, with options to specify an out_dir,select frame rate, and resize images by percent
    default framerate = 7 frames per second or 1 week per second if images are sorted by time of day to utilize a single image
    per day, which is recommended to reduce changes in water elevation and flickering from variable lighting at different times of day
    
    """
    current_date = datetime.now().strftime('%Y%m%d')
    output_file = f'{site_name}_timelapse_{current_date}.mp4'
    output_file = os.path.join(out_dir, output_file)

    if len(image_files) == 0:
        print("No images to process.")
        return None
        # Initialize VideoWriter with the first frame's dimensions after resizing
    first_frame = cv2.imread(image_files[0])
    if resize_percent != 100:
        first_frame = resize_image(first_frame, resize_percent)
    height, width, layers = first_frame.shape
    size = (width, height)
    out = cv2.VideoWriter(output_file, cv2.VideoWriter_fourcc(*'mp4v'), frame_rate, size)
    #out = cv2.VideoWriter(output_file, cv2.VideoWriter_fourcc(*'XVID'), frame_rate, size) # if you want .avi format
    n_images = 1
    nn = len(image_files)
    for filename in image_files:
        print(f'processing image {filename} - {n_images} out of {nn}') 
        img = cv2.imread(filename)
        if resize_percent != 100:
            img = resize_image(img, resize_percent)
        date_time = parse_filename(os.path.basename(filename))
        date_str = date_time.strftime('%Y-%m-%d %H:%M')
        put_date_on_image(img, date_str)
        out.write(img)
        n_images = n_images+1
        #get_file_size(filename)

    out.release()
    vid_size = get_file_size(output_file)
    
    return output_file

# %%
# Example usage
folder_path = image_dir22_web  # Replace with your images directory path
site_name = 'RC0220Ra_web'  # Replace with your site name

'''
Due to variable lighting in the canyon throughout the day, and the variable water levels,
its advisable to limit the timelapse to a single image per day rather than 5 per day. utlizing
the start_time and end_time arguments. All times in MST military time 00:00 - 24:59 %H:%M

If not using web-res images, is suggested to re-size images by at least 25% to prevent very large video files
'''
start_time = datetime.strptime('10:00', '%H:%M').time()
end_time = datetime.strptime('13:00', '%H:%M').time()

resize_percent = 100  # Resize images to 50% of their original size
print('filtering images')
filtered_files = filter_images(folder_path, start_time, end_time)
print('Images filtered')
print('creating timelapse')
filtered_files = filtered_files[0:100] # to test script on subset of data, use this line, otherwise comment out for full timelapse
video_filename = create_timelapse(site_name, filtered_files,out_dir = os.getcwd(), frame_rate=7, resize_percent=resize_percent)
if video_filename:
    print(f"Timelapse video created: {video_filename}")
# Out:
# filtering images
# The Directory M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra contains 2872 within the specified start_time, end_time range
# The first image is M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960216_1000_web.jpg and the last image of the series is M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_20160514_1147_web.jpg
# Images filtered
# creating timelapse
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960216_1000_web.jpg - 1 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960217_1000_web.jpg - 2 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960218_1000_web.jpg - 3 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960219_1000_web.jpg - 4 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960220_1000_web.jpg - 5 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960221_1000_web.jpg - 6 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960222_1000_web.jpg - 7 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960224_1000_web.jpg - 8 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960225_1000_web.jpg - 9 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960227_1000_web.jpg - 10 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960228_1000_web.jpg - 11 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960304_1000_web.jpg - 12 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960310_1000_web.jpg - 13 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19960313_1000_web.jpg - 14 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961025_1200_web.jpg - 15 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961026_1200_web.jpg - 16 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961027_1200_web.jpg - 17 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961028_1200_web.jpg - 18 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961029_1200_web.jpg - 19 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961030_1200_web.jpg - 20 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961031_1200_web.jpg - 21 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961101_1200_web.jpg - 22 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961102_1200_web.jpg - 23 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961103_1200_web.jpg - 24 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961104_1200_web.jpg - 25 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961105_1200_web.jpg - 26 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961106_1200_web.jpg - 27 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961107_1200_web.jpg - 28 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961108_1200_web.jpg - 29 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961109_1200_web.jpg - 30 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961110_1200_web.jpg - 31 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961111_1200_web.jpg - 32 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961112_1200_web.jpg - 33 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961113_1200_web.jpg - 34 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961114_1200_web.jpg - 35 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961115_1200_web.jpg - 36 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961116_1200_web.jpg - 37 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961117_1200_web.jpg - 38 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961118_1200_web.jpg - 39 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961119_1200_web.jpg - 40 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961120_1200_web.jpg - 41 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961121_1200_web.jpg - 42 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961122_1200_web.jpg - 43 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961123_1200_web.jpg - 44 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961124_1200_web.jpg - 45 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961125_1200_web.jpg - 46 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961126_1200_web.jpg - 47 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19961127_1200_web.jpg - 48 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970214_1200_web.jpg - 49 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970215_1200_web.jpg - 50 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970216_1200_web.jpg - 51 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970217_1200_web.jpg - 52 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970218_1200_web.jpg - 53 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970219_1200_web.jpg - 54 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970220_1200_web.jpg - 55 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970221_1200_web.jpg - 56 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970222_1200_web.jpg - 57 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970223_1200_web.jpg - 58 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970224_1200_web.jpg - 59 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970225_1200_web.jpg - 60 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970226_1200_web.jpg - 61 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970227_1200_web.jpg - 62 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970228_1200_web.jpg - 63 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970301_1200_web.jpg - 64 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970302_1200_web.jpg - 65 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970303_1200_web.jpg - 66 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970304_1200_web.jpg - 67 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970305_1200_web.jpg - 68 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970306_1200_web.jpg - 69 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970307_1200_web.jpg - 70 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970308_1200_web.jpg - 71 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970309_1200_web.jpg - 72 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970310_1200_web.jpg - 73 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970311_1200_web.jpg - 74 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970312_1200_web.jpg - 75 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970313_1200_web.jpg - 76 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970314_1200_web.jpg - 77 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970315_1200_web.jpg - 78 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970316_1200_web.jpg - 79 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970317_1200_web.jpg - 80 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970318_1200_web.jpg - 81 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970319_1200_web.jpg - 82 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970320_1200_web.jpg - 83 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970321_1200_web.jpg - 84 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970322_1200_web.jpg - 85 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970422_1030_web.jpg - 86 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970423_1030_web.jpg - 87 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970424_1030_web.jpg - 88 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970425_1030_web.jpg - 89 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970426_1030_web.jpg - 90 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970427_1030_web.jpg - 91 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970428_1030_web.jpg - 92 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970429_1030_web.jpg - 93 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970430_1030_web.jpg - 94 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970501_1030_web.jpg - 95 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970502_1030_web.jpg - 96 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970503_1030_web.jpg - 97 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970504_1030_web.jpg - 98 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970505_1030_web.jpg - 99 out of 100
# processing image M:/Ryan_Lima/Remote Cameras/web_res/RC0220Ra\RC0220Ra_19970506_1030_web.jpg - 100 out of 100
# File: C:\Users\rl587\Documents\Python Scripts\Sandbars\Timelapse\RC0220Ra_web_timelapse_20231215.mp4, Size: 11998.05 KB
# Timelapse video created: C:\Users\rl587\Documents\Python Scripts\Sandbars\Timelapse\RC0220Ra_web_timelapse_20231215.mp4
